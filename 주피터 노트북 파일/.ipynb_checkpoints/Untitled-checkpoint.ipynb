# %%
import folium
import pandas as pd
import json
import requests
import branca
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %%
m = folium.Map(location=[37.571076, 126.995880])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map.html')

# %%
m = folium.Map(
    location=[37.571076, 126.995880],
    tiles='Stamen Terrain',
    zoom_start=13
)

tooltip = "Click me"
folium.Marker(
    [37.555150, 126.970538],
    popup='<b>Seoul Station</b>',
    tooltip=tooltip
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.read_csv('charge.csv')
df.head()
# Out:
#              statnm    statid  chgerid  chgertype              addrdoro  \
# 0          종묘 공영주차장  11110003        1          3      서울특별시 종로구 종로 157
# 1         세종로 공영주차장  11110006        1          6    서울특별시 종로구 세종대로 189
# 2        그랜드앰배서더 서울  11140018        1          6      서울특별시 중구 동호로 287
# 3        한강진역 공영주차장  11170004        1          3  서울특별시 용산구 한남동 산10-84
# 4  마장동사무소 앞(공중전화부스)  11200006        1          6     서울특별시 성동구 마장동 808
#
#          lat         lng    usetime  stat
# 0  37.571076  126.995880  24시간 이용가능     2
# 1  37.573611  126.976011  24시간 이용가능     3
# 2  37.559352  127.002350  24시간 이용가능     5
# 3  37.540085  127.002804  24시간 이용가능     2
# 4  37.566094  127.045526  24시간 이용가능     2

# %%
import json

url = 'https://github.com/PinkWink/DataScience.git'
vis1 = json.loads(requests.get(f'{url}/pydata/02. skorea_municipalities_geo_simple.json').text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-1c70b050a492> in <module>()
#       5
#       6 geo_path = vis1
# ----> 7 geo_str = json.load(open(geo_path, encoding='utf-8'))
#
# TypeError: expected str, bytes or os.PathLike object, not dict

# %%
geo_path = 'korea_seoul.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='stamentoner')

map.choropleth(geo_data = geo_str)

map
# Out:
# C:\Users\ieeho\Anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#폰트설정
from matplotlib import font_manager, rc

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
